# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/allegheny-college-cmpsc-106-spring-2026/data-display-starter/blob/main/data_display_starter.ipynb)

# %% [markdown]
# TODO: Click on the badge above, then `Copy to Drive` before continuing.

# %% [markdown]
# TODO: double click and replace this text with your name

# %% [markdown]
# # Data Display Lab
#
# ---
#
# In this lab, you will use fundamental data displays to find hidden patterns in data.
#
# This lab should be completed during the lab meeting time, but modifations may be made until the official deadline of 4:15pm on January 27th.
#
# ## Learning Outcomes
#
# By completing this lab you will
#
# - explore a dataset by using built-in display types from matplotlib
# - explore a dataset by plugging in different parts of the data
# - write a reflection in a markdown cell
# - modify a url to your work to make it accessible
# - update a GitHub Repository
# - check gatorgrade in GitHub Actions
#
# ## Reminders
#
# - If needed, one of four available automatic extension tokens can be applied by using the form on found on the course syllabys.
# - If you have a question, post in the 105 Discord channel.
# - Refer to previous materials to learn how to use Notebooks in Google Colab, make your work accessible, submit, and check your work.
#
# ## Getting Started
#
# - Below you will see some starter code to load a [mystery dataset](https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/data-display-starter/main/data/data-display.csv) into a pandas dataframe, `df`. The columns of the dataframe are called `Mystery 1`, `Mystery 2`, `Mystery 3`, `Mystery 4`.
#
# - Modify the display-generating code below to use the appropriate column names. Note that the code will not run until appropriate names have been supplied.
#
# - **Your job is to figure out what hidden thing the data contains. Specifically, one type of data display with certain columns will make a meaningful plot.**
#
# - At the end of this document, write two real paragraphs on how you went about exploring the data, and what you found.
#
# - Don't forget to answer all `T O D O` markers and to remove the markers.
#
# ## Saving Your Work
#
# Saving your work and making it accessible is a required part of all labs.
#
# ### Accessability Part 1
#
# Make sure that all cells have been executed and are SHOWING their outputs.
#
# In order to make this file accessible you will have to edit the very top badge that looks like this: ![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg).
#
# - Double click next to the top badge to take a look at the urls inside.
# - You should see this: `https://githubtocolab.com/allegheny-college-cmpsc-105-spring-2026/data-display-starter/blob/main/data_display_starter.ipynb)`
# - Change the word `starter` to your github user name.
#
# ### Saving
#
# This notebook is running on a distant Google server and deletes what you've done when you close this tab. To save your work for later use or analysis you have a few options:
#
# - File > "Save a copy in Drive" will save it to you Google Drive in a folder called "Colaboratory". You can run it later from there.
# - File > "Download .ipynb" to save to your computer (and run with Jupyter software later)
# - Save an image to your computer of a graph or chart, right-click on it and select Save Image as ...
#
# I would recommend a workflow of `Copy to Drive --> editing/running/testing --> downloading`. You should have already hit `Copy to Drive`, but if you haven't, then please do so now. Then go ahead and download the file.
#
# ### Accessibility Part 2
#
# If you are satisfied with your work, you can now upload the downloaded file to your GitHub repo!
#
# - New students should use GitHub to upload the file.
#   - Next to the green code button in GitHub, you will see an `add file` button. Click that, then choose the downloaded notebook from your computer.
# - If you know what `git` is, you may use it.
#
# ## Checking Your Work
#
# ### Check your file output
#
# Once your file is uploaded, please open it on GitHub. All the outputs and plots should be showing. If they are not showing, this means that not all code cells were executed before you downloaded your file.
#
# ### Check your badge
#
# Check that the badge is working by clicking on it. It should take you into Google Colab with **your** file (not the starter file).
#
# ### Check GitHub Actions
#
# Back in GitHub, go to the Actions tab. Click on the top Action to see a report about your T O D Os. If the T O D Os have been done and deleted, then the actions  will show that gatorgrade reports 100%. This is not your grade, but it is a good indication that you did not forget to do something.
#
# If you see remaining T O D Os, then you may want to edit and update your file.

# %%
# TODO: Replace this comment with short note about what this code cell does

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    'https://raw.githubusercontent.com/allegheny-college-cmpsc-105-spring-2026/data-display-starter/main/data/data-display.csv',
    sep=',',
    names=['Mystery1', 'Mystery2', 'Mystery3', 'Mystery4'],
    skiprows=0
)

print(df.head()) # Display the first few rows of the DataFrame

# %%
# Assuming df is already created in the previous code
plt.figure()
plt.scatter(df[''], df['']) # TODO: Create a scatter plot to explore the relationship between two variables
plt.xlabel('') # TODO: Choose one column for the x-axis.
plt.ylabel('') # TODO: Choose one column for the y-axis.
plt.title('') # TODO: Add a descriptive title that explains what is being compared
plt.grid(True)
plt.show()

# %%
# Assuming df is already created in the previous code
plt.figure()
plt.pie(df[''], labels=df['']) # TODO: Create a pie chart using values from one column, and use another column to label each slice
plt.title('') # TODO: Add a descriptive title for the pie chart
plt.show()

# %%
# Assuming df is already created in the previous code
plt.figure()
plt.hist(df[''], bins=20) # TODO: Choose an appropriate column for the histogram
plt.xlabel('') # TODO: Label the x-axis
plt.ylabel('') # TODO: Label the y-axis
plt.title('') # TODO: Add a title describing what the histogram shows
plt.show()

# %%
# Assuming df is already created in the previous code
plt.figure()  # Adjust figure size for better visualization
plt.plot(df[''], df[''], marker='o', linestyle='-') # TODO: Choose a column for the x-axis and a column for the y-axis
plt.xlabel('') # TODO: Label the x-axis
plt.ylabel('') # TODO: Label the y-axis
plt.title('') # TODO: Add a descriptive title for the line chart
plt.grid(True, linestyle='--', alpha=0.7)  # Add a grid for better readability
plt.xticks(rotation=45) # Rotate x-axis labels for better visibility
plt.show()

# %%
# Assuming df is already created in the previous code
plt.figure()
plt.boxplot(df[''])  # Create the boxplot # TODO: Choose a column to visualize
plt.xlabel('') # TODO: Label the x-axis
plt.title('') # TODO: Add a descriptive title
plt.show()

# %% [markdown]
# # Reflection

# %% [markdown]
# TODO: Write your reflection here.
#
# - As a reminder, your job is to figure out what hidden thing the data above contains. Specifically, one type of data display with certain columns will make a meaningful plot.
#
# - Write two real paragraphs on how you went about exploring the data, and what you found.
#
# - So far, what is the value of data exploration through data display?
